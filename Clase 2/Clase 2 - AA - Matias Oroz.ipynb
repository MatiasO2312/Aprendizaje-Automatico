# %%
import pandas as pd

# Cargar archivo CSV
ventas = pd.read_csv("/content/sample_data/ventas (1).csv")

# Cargar archivo JSON
clientes = pd.read_json("/content/sample_data/clientes.json")

# Cargar archivo Excel
inventario = pd.read_excel("/content/sample_data/inventario.xlsx")

# Mostrar primeras filas de ventas
print("Vista previa de ventas:")
print(ventas.head())

# Mostrar cantidad total de clientes
print("\nCantidad total de clientes:", len(clientes))

# Calcular promedio de stock
promedio_stock = inventario["stock"].mean()
print("\nPromedio de stock disponible:", promedio_stock)
# Out:
# Vista previa de ventas:
#    id_venta       fecha  producto  cantidad  precio_unitario
# 0         1  2026-01-10  Notebook         2             1200
# 1         2  2026-01-12     Mouse         5               25
# 2         3  2026-01-15   Teclado         3               45
# 3         4  2026-01-18   Monitor         1              300
#
# Cantidad total de clientes: 3
#
# Promedio de stock disponible: 26.25

# %% [markdown]
# ### 1. Usar la opción 'Guardar una copia en GitHub' de Colab (Recomendado)
#
# La manera más directa de guardar una copia de tu notebook actual en GitHub es a través del menú de Colab:
#
# 1.  Ve a `Archivo` (File) en la barra de menú superior.
# 2.  Selecciona `Guardar una copia en GitHub...` (Save a copy in GitHub...).
# 3.  Colab te pedirá que autorices GitHub si no lo has hecho antes.
# 4.  En el cuadro de diálogo que aparece, selecciona tu repositorio (`MatiasO2312/Aprendizaje-Automatico`).
# 5.  **Muy importante:** Asegúrate de navegar a la carpeta `Clase 2` antes de guardar. Colab te permitirá especificar la ruta dentro del repositorio. Pon un nombre significativo al archivo (e.g., `mi_clase_actual.ipynb`).
# 6.  Haz clic en `OK` o `Guardar`.
#
# Esto creará un nuevo commit en tu repositorio con este notebook en la ubicación deseada.

# %% [markdown]
# ### 2. Guardar y empujar los cambios manualmente con Git (Método Avanzado)
#
# Si prefieres tener más control o si la opción anterior no funciona por alguna razón, puedes hacerlo manualmente clonando el repositorio y luego empujando el archivo.
#
# Primero, clona tu repositorio en el entorno de Colab. Asegúrate de que no haya ya una carpeta llamada `Aprendizaje-Automatico` en `/content/` para evitar conflictos.

# %%
# Clona el repositorio de GitHub
# !git clone https://github.com/MatiasO2312/Aprendizaje-Automatico.git

# Verifica que el repositorio se haya clonado y lista el contenido de la carpeta 'Clase 2'
# !ls /content/Aprendizaje-Automatico/Clase\ 2/

# %% [markdown]
# Una vez clonado el repositorio, necesitarás:
#
# 1.  **Descargar este notebook:** Ve a `Archivo` > `Descargar` > `Descargar .ipynb` en el menú de Colab. Esto descargará el archivo de este notebook a tu computadora local.
# 2.  **Subir el archivo descargado a la carpeta correcta en Colab:** Usa el panel de archivos de Colab (el ícono de la carpeta a la izquierda) para navegar a `/content/Aprendizaje-Automatico/Clase 2/` y sube el archivo `.ipynb` que acabas de descargar.
#     *Opcional: Si el archivo descargado está en `/content/` (lo cual es poco probable directamente desde una descarga del navegador), puedes moverlo con `!mv tu_notebook.ipynb /content/Aprendizaje-Automatico/Clase\ 2/`.*

# %% [markdown]
# 3.  **Configurar Git y empujar los cambios:** Para empujar cambios a tu repositorio de GitHub, necesitarás un [Token de Acceso Personal (PAT) de GitHub](https://docs.github.com/es/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token). Deberías almacenarlo de forma segura como un secreto de Colab (busca el icono de la llave en el panel izquierdo y dale el nombre `GITHUB_TOKEN`).

# %%
from google.colab import userdata

# Recupera tu token de GitHub de los secretos de Colab
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# Configura tu usuario y email de Git (ajusta con tu información)
# !git config --global user.email "tu_email@example.com"
# !git config --global user.name "Tu Nombre de Usuario GitHub"

# Navega al directorio del repositorio clonado
# %cd /content/Aprendizaje-Automatico

# Agrega el nuevo archivo (o archivos modificados) a la zona de stage
# Reemplaza 'Clase 2/nombre_de_tu_notebook.ipynb' con la ruta y el nombre real del archivo
# !git add Clase\ 2/nombre_de_tu_notebook.ipynb

# Realiza un commit con un mensaje descriptivo
# !git commit -m "Agregado el notebook de Clase 2 desde Colab"

# Empuja los cambios a GitHub usando tu token
# !git push https://{GITHUB_TOKEN}@github.com/MatiasO2312/Aprendizaje-Automatico.git

# %% [markdown]
# Recuerda reemplazar `tu_email@example.com`, `Tu Nombre de Usuario GitHub`, y `Clase 2/nombre_de_tu_notebook.ipynb` con tus datos reales.
